# %%
import pandas as pd
pd.options.display.max_columns = 99
pd.options.display.max_rows = 999

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_csv('./Preguntas/niveles_educativos.csv')
radio_ref = pd.read_csv('./Radios_censales/radio_ref.csv')

# %%
# AMBA y La Plata
radios = radio_ref.loc[(radio_ref.AGLOMERADO == 33) | (radio_ref.AGLOMERADO == 32)| (radio_ref.AGLOMERADO == 2)]
radios = radios[['RADIO_REF_ID', 'DPTO', 'NOMDPTO', 'PROV','NOMPROV']]

# %%
radios.merge(df).sample(100)
# Out:
#        RADIO_REF_ID  DPTO              NOMDPTO  PROV  \
# 7782           7794  6434                Lanús     6
# 11122         11150  6756           San Isidro     6
# 12272         12321  6840      Tres de Febrero     6
# 8305           8317  6490      Lomas de Zamora     6
# 6127           6138  6410            Ituzaingó     6
# 13807         18614  6441             La Plata     6
# 1516           1518  2007            Comuna 07     2
# 5493           5504  6371   General San Martín     6
# 10583         10597  6658              Quilmes     6
# 4272           4277  6035           Avellaneda     6
# 10491         10505  6658              Quilmes     6
# 6257           6268  6412          José C. Paz     6
# 4155           4160  6035           Avellaneda     6
# 10944         10958  6749         San Fernando     6
# 10159         10173  6568                Morón     6
# 1555           1557  2007            Comuna 07     2
# 13935         19478  6525           Marcos Paz     6
# ...
