# %%
from arcgis.gis import GIS
gis = GIS("https://matuteiglesias.maps.arcgis.com", "matuteiglesias123", "matute012")
map1 = my_gis.map()

# %%
items = gis.content.search('Red_agua_24_provs_52408_rws_11_cls')

for item in items:
    display(item)
# Out:
# <Item title:"Red_agua_24_provs_52408_rws_11_cls" type:Feature Layer Collection owner:matuteiglesias123>
# <Item title:"Red_agua_24_provs_52408_rws_11_cls" type:GeoJson owner:matuteiglesias123>

# %%
item_to_add = [temp_item for temp_item in items if temp_item.type == "Feature Service"]
map1.add_layer(item_to_add)

# %%
map1
# Out:
# MapView(jupyter_target='notebook', layout=Layout(height='400px', width='100%'), ready=True)
